# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# ML Libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.svm import SVC
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

# %%
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jainambarbhaya1509/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/jainambarbhaya1509/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/jainambarbhaya1509/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# # Importing DataFrame

# %%
mental_health = pd.read_csv("Dataset//mental-health.csv")
mental_health.head(6)
# Out:
#                                                 text         label
# 0  I recently went through a breakup and she said...    depression
# 1  I do not know how to navigate these feelings, ...    depression
# 2  So I have been with my bf for 5 months , and h...    depression
# 3  I am so exhausted of this. Just when I think I...  SuicideWatch
# 4  I have been severly bullied since i was 5 till...    depression
# 5  I am 20 year old with some good friends but I ...  SuicideWatch

# %% [markdown]
# # Data Visualization & Transformation

# %%
mental_health.size
# Out:
# 40728

# %%
mental_health.shape
# Out:
# (20364, 2)

# %%
distinct_values = np.unique(mental_health["label"], return_counts=True)
distinct_values
# Out:
# (array(['SuicideWatch', 'depression'], dtype=object), array([ 9993, 10371]))

# %%
classes = mental_health["label"].unique()
pd.DataFrame(np.unique(mental_health["label"], return_counts=True), index=["Value", "count"])
# Out:
#                   0           1
# Value  SuicideWatch  depression
# count          9993       10371

# %%
mental_health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20364 entries, 0 to 20363
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    20364 non-null  object
#  1   label   20364 non-null  object
# dtypes: object(2)
# memory usage: 318.3+ KB

# %%
# Plot class distribution
plt.figure(figsize=(4, 2))
sns.countplot(data=mental_health, x="label", width=0.3)
plt.xlabel("Class")
plt.ylabel("Count")
plt.title("Class Distribution")
plt.show()

# %% [markdown]
# # Data Splitting

# %%
x = mental_health.text
y = mental_health.label

# %%
pd.set_option('display.max_colwidth', None)

# %%
# Lowercasing
mental_health['text']= mental_health['text'].str.lower()

# Removing Punctuations
mental_health['text'] = mental_health['text'].str.replace(r'[^\w\s]+', '',regex = True)

# Removing Stop Words
stop_words = stopwords.words('english')
mental_health['text'] = mental_health['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))

# Tokenizing
mental_health['text'] = mental_health['text'].apply(lambda x:nltk.word_tokenize(x))

# Lemmatizing
lem = WordNetLemmatizer()
mental_health['text'] = mental_health['text'].apply(lambda x : [lem.lemmatize(i, pos='v') for i in x])
mental_health['text'] = mental_health['text'].apply(lambda x : ' '.join(x))

mental_health.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          text  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   recently go breakup say still want friends say try talk things always hurt want lose feel pain stop hurt much can not even cry want hurt say want never speak know together always hurt know still love wish never meet would much less painful lose feel
# 1                                                                                                                   know navigate feel new feel stretch understand go pleasantly fine suicidal self loathe within minutes able step suffer poor mental health 10 years turn 26 next week feel ashamed serious negative thoughts covid hard transition especially move new city months everything start lock settle love partner great connection family really fun job finish degree stop look around feel like nothing ever good enough never good enough always skin problems bad teeth acne never artist use bachelor fine art drive passionate use never career build entire plan around lose interest art never relationship family want could stand stay hometown feel tornado failures swirl around damn time seem matter many positives come way last long enough weight negative really know look guess want say loud whatever 0 100
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   bf 5 months already tell depress week nothing particular happen feel hes bother ask sleep together things etci know problem aware want ask without suffocate really clingy thing usually love right kind feel muchany suggestion gladly accept frank tell make worse bother bf 21 bad time due depression
# 3  exhaust think finally rest think maybe things start settle another hurdle come fly month alone find mum could die girlfriend leave parent reveal want divorce grandad hospitalise little sisters rush aampe possible brain damage god must fuck hate like life try get kill honestly think would better dead attempt 12 stupid way could cut deep enough 15 everything much worse ever can not hold much longer go take miracle get feel alone feel like world hat idea wrong deserve think get better well everythings come crash think carbon monoxide poison highly doubt way get look like overdose unreliable fuck survive sound like hell idk get stick around long enough make sure sisters alright already contact one exs friends make sure look go think long leave sorry post subreddit many time span week probably really annoy absolutely idea anymore feel sick sister die really can not anymore hurt life really fuck try
# 4                                                                                                                                                                                                                                                                                                                                                        severly bully since 5 till 15 result depress misanthrope ptss multiple anxiaty dissorders 18 friendsor social contact study online meet people sport since poor health sick child drink go bar meet new people like party festivals since crowd filthy date sit shit since people superficial even rare ocasion get match message get response do wonderfull close family love alot want deal constant loneliness anyone recomandation wich activatys would bring contact people hobbies special intrest besides obsesive facination war reason etc long suposed go better days come
#
#           label
# 0    depression
# 1    depression
# 2    depression
# 3  SuicideWatch
# 4    depression

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# # Model Preparation & Evaluation

# %%
analyzer='word'
ngram_range = (1, 5)
min_df = 3
max_df = 0.8 
max_features = 5000 
stop_words = 'english'
sublinear_tf = True

# %% [markdown]
# ### Logistic Regression

# %%
lr = Pipeline([
    ('tfidf', TfidfVectorizer(
        analyzer=analyzer,
        ngram_range=ngram_range,
        min_df=min_df,
        max_df=max_df,
        max_features=max_features,
        sublinear_tf=sublinear_tf
    )),
    ('lrc', LogisticRegression(max_iter=1000, random_state=42))  
])
lr.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_df=0.8, max_features=5000, min_df=3,
#                                  ngram_range=(1, 5), sublinear_tf=True)),
#                 ('lrc', LogisticRegression(max_iter=1000, random_state=42))])

# %%
y_pred = lr.predict(x_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

# Print the accuracy
print("Logistic Regression Accuracy:", accuracy)
print(y_test[:11])
print(y_pred[:11])
# Out:
# Logistic Regression Accuracy: 0.7409771667075865
# 5960     SuicideWatch
# 8309       depression
# 13142      depression
# 12949    SuicideWatch
# 5174     SuicideWatch
# 1534     SuicideWatch
# 1328     SuicideWatch
# 19277      depression
# 4436     SuicideWatch
# 3353     SuicideWatch
# 6097     SuicideWatch
# Name: label, dtype: object
# ['SuicideWatch' 'depression' 'depression' 'depression' 'depression'
#  'SuicideWatch' 'SuicideWatch' 'depression' 'SuicideWatch' 'depression'
#  'depression']

# %%
lr_model = lr.named_steps['lrc'] 
feature_names = lr.named_steps['tfidf'].get_feature_names_out()
coefficients = lr_model.coef_[0]
coefficient_df = pd.DataFrame({'Feature': feature_names, 'Coefficient': coefficients})

coefficient_df = coefficient_df.reindex(coefficient_df['Coefficient'].abs().sort_values(ascending=False).index)

# Plot
plt.figure(figsize=(8, 4))
sns.barplot(data=coefficient_df.head(10), x='Coefficient', y='Feature', palette='viridis')
plt.xlabel('Coefficient')
plt.ylabel('Feature')
plt.title('Top Feature Coefficients')
plt.show()

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(5, 3))

class_names = mental_health['label'].unique()
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()

# %%
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
# SuicideWatch       0.75      0.73      0.74      2029
#   depression       0.74      0.75      0.74      2044
#
#     accuracy                           0.74      4073
#    macro avg       0.74      0.74      0.74      4073
# weighted avg       0.74      0.74      0.74      4073

# %% [markdown]
# ### K-Nearest Neighbor

# %%
knn = Pipeline([
    ('tfidf', TfidfVectorizer(
        ngram_range=ngram_range,
        min_df=min_df,
        max_df=max_df,
        max_features=max_features,
        stop_words=stop_words,
        sublinear_tf=sublinear_tf
    )),
    ('knn', KNeighborsClassifier(n_neighbors=599))
])
knn.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_df=0.8, max_features=5000, min_df=3,
#                                  ngram_range=(1, 5), stop_words='english',
#                                  sublinear_tf=True)),
#                 ('knn', KNeighborsClassifier(n_neighbors=599))])

# %%
y_pred = knn.predict(x_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

# Print the accuracy
print("KNN Accuracy:", accuracy)
print(y_test[:11])
print(y_pred[:11])
# Out:
# KNN Accuracy: 0.7242818561257058
# 5960     SuicideWatch
# 8309       depression
# 13142      depression
# 12949    SuicideWatch
# 5174     SuicideWatch
# 1534     SuicideWatch
# 1328     SuicideWatch
# 19277      depression
# 4436     SuicideWatch
# 3353     SuicideWatch
# 6097     SuicideWatch
# Name: label, dtype: object
# ['SuicideWatch' 'depression' 'depression' 'depression' 'SuicideWatch'
#  'SuicideWatch' 'depression' 'depression' 'SuicideWatch' 'depression'
#  'depression']

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(5, 3))
class_names = mental_health['label'].unique()
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()

# %%
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
# SuicideWatch       0.75      0.67      0.71      2029
#   depression       0.70      0.78      0.74      2044
#
#     accuracy                           0.72      4073
#    macro avg       0.73      0.72      0.72      4073
# weighted avg       0.73      0.72      0.72      4073

# %% [markdown]
# ### Naive Bayes(Multinomia)

# %%
nb_classifier = Pipeline([
    ('tfidf', TfidfVectorizer(
        ngram_range=ngram_range,
        min_df=min_df,
        max_df=max_df,
        max_features=max_features,
        stop_words=stop_words,
        sublinear_tf=sublinear_tf
    )),
    ('nbc', MultinomialNB())
])
nb_classifier.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_df=0.8, max_features=5000, min_df=3,
#                                  ngram_range=(1, 5), stop_words='english',
#                                  sublinear_tf=True)),
#                 ('nbc', MultinomialNB())])

# %%
y_pred = nb_classifier.predict(x_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

# Print the accuracy
print("MultinomiaNB Accuracy:", accuracy)
print(y_test[:11])
print(y_pred[:11])
# Out:
# MultinomiaNB Accuracy: 0.7301743186840167
# 5960     SuicideWatch
# 8309       depression
# 13142      depression
# 12949    SuicideWatch
# 5174     SuicideWatch
# 1534     SuicideWatch
# 1328     SuicideWatch
# 19277      depression
# 4436     SuicideWatch
# 3353     SuicideWatch
# 6097     SuicideWatch
# Name: label, dtype: object
# ['SuicideWatch' 'depression' 'depression' 'depression' 'SuicideWatch'
#  'SuicideWatch' 'SuicideWatch' 'depression' 'SuicideWatch' 'depression'
#  'depression']

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(5, 3))
class_names = mental_health['label'].unique()
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()

# %%
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
# SuicideWatch       0.73      0.72      0.73      2029
#   depression       0.73      0.74      0.73      2044
#
#     accuracy                           0.73      4073
#    macro avg       0.73      0.73      0.73      4073
# weighted avg       0.73      0.73      0.73      4073

# %% [markdown]
# ### Decision Tree

# %%
decision_tree_classifier = Pipeline([
    ('tfidf', TfidfVectorizer(
        ngram_range=ngram_range,
        min_df=min_df,
        max_df=max_df,
        max_features=max_features,
        stop_words=stop_words,
        sublinear_tf=sublinear_tf
    )),           
    ('dtc', DecisionTreeClassifier(max_depth=10, random_state=42))       
])
decision_tree_classifier.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_df=0.8, max_features=5000, min_df=3,
#                                  ngram_range=(1, 5), stop_words='english',
#                                  sublinear_tf=True)),
#                 ('dtc', DecisionTreeClassifier(max_depth=10, random_state=42))])

# %%
y_pred = decision_tree_classifier.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
print("Decision Tree Accuracy:", accuracy)
print(y_test[:11])
print(y_pred[:11])
# Out:
# Decision Tree Accuracy: 0.6729683280137491
# 5960     SuicideWatch
# 8309       depression
# 13142      depression
# 12949    SuicideWatch
# 5174     SuicideWatch
# 1534     SuicideWatch
# 1328     SuicideWatch
# 19277      depression
# 4436     SuicideWatch
# 3353     SuicideWatch
# 6097     SuicideWatch
# Name: label, dtype: object
# ['SuicideWatch' 'depression' 'depression' 'SuicideWatch' 'SuicideWatch'
#  'SuicideWatch' 'SuicideWatch' 'SuicideWatch' 'depression' 'depression'
#  'depression']

# %%
feature_names = decision_tree_classifier.named_steps['tfidf'].get_feature_names_out()
feature_importances = decision_tree_classifier.named_steps['dtc'].feature_importances_
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

plt.figure(figsize=(8, 4))
sns.barplot(data=feature_importance_df.head(10), x='Importance', y='Feature', palette='viridis')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Top Feature Importances')
plt.show()

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(5, 3))
class_names = mental_health['label'].unique()
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()

# %%
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
# SuicideWatch       0.64      0.78      0.70      2029
#   depression       0.72      0.57      0.64      2044
#
#     accuracy                           0.67      4073
#    macro avg       0.68      0.67      0.67      4073
# weighted avg       0.68      0.67      0.67      4073

# %% [markdown]
# ### Random Forest Tree

# %%
random_forest_classifier = Pipeline([
    ('tfidf', TfidfVectorizer(
        ngram_range=ngram_range,
        min_df=min_df,
        max_df=max_df,
        max_features=max_features,
        stop_words=stop_words,
        sublinear_tf=sublinear_tf
    )),                
    ('rfc', RandomForestClassifier(n_estimators=400, random_state=42))
])
random_forest_classifier.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_df=0.8, max_features=5000, min_df=3,
#                                  ngram_range=(1, 5), stop_words='english',
#                                  sublinear_tf=True)),
#                 ('rfc',
#                  RandomForestClassifier(n_estimators=400, random_state=42))])

# %%
y_pred = random_forest_classifier.predict(x_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

# Print the accuracy
print("Random Forest Tree Accuracy:", accuracy)
print(y_test[:11])
print(y_pred[:11])
# Out:
# Random Forest Tree Accuracy: 0.7333660692364351
# 5960     SuicideWatch
# 8309       depression
# 13142      depression
# 12949    SuicideWatch
# 5174     SuicideWatch
# 1534     SuicideWatch
# 1328     SuicideWatch
# 19277      depression
# 4436     SuicideWatch
# 3353     SuicideWatch
# 6097     SuicideWatch
# Name: label, dtype: object
# ['SuicideWatch' 'depression' 'depression' 'depression' 'SuicideWatch'
#  'SuicideWatch' 'SuicideWatch' 'depression' 'SuicideWatch' 'depression'
#  'depression']

# %%
feature_names = random_forest_classifier.named_steps['tfidf'].get_feature_names_out()
feature_importances = random_forest_classifier.named_steps['rfc'].feature_importances_
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)


plt.figure(figsize=(8, 4))
sns.barplot(data=feature_importance_df.head(10), x='Importance', y='Feature', palette='viridis')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Top Feature Importances')
plt.show()

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(5, 3))
class_names = mental_health['label'].unique()
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()

# %%
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
# SuicideWatch       0.73      0.73      0.73      2029
#   depression       0.73      0.73      0.73      2044
#
#     accuracy                           0.73      4073
#    macro avg       0.73      0.73      0.73      4073
# weighted avg       0.73      0.73      0.73      4073

# %% [markdown]
# ### Support Vector Machine

# %%
svm = Pipeline([
    ('tfidf', TfidfVectorizer(
        ngram_range=ngram_range,
        min_df=min_df,
        max_df=max_df,
        max_features=max_features,
        stop_words=stop_words,
        sublinear_tf=sublinear_tf
    )),         
    ('svmc', SVC(kernel="rbf", random_state=42))                    
])
svm.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_df=0.8, max_features=5000, min_df=3,
#                                  ngram_range=(1, 5), stop_words='english',
#                                  sublinear_tf=True)),
#                 ('svmc', SVC(random_state=42))])

# %%
y_pred = svm.predict(x_test)

# Calculate accuracyY
accuracy = accuracy_score(y_test, y_pred)

# Print the accuracy
print("SVM Accuracy:", accuracy)
# Out:
# SVM Accuracy: 0.7382764547016941

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(5, 3))
class_names = mental_health['label'].unique()
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()

# %%
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
# SuicideWatch       0.74      0.74      0.74      2029
#   depression       0.74      0.74      0.74      2044
#
#     accuracy                           0.74      4073
#    macro avg       0.74      0.74      0.74      4073
# weighted avg       0.74      0.74      0.74      4073

# %% [markdown]
# ### Voting Classifier

# %%
voting_classifier = VotingClassifier(
    estimators=[
        ('lrc', lr),
        ('knn', knn),
        ('nbc', nb_classifier),
        ('dtc', decision_tree_classifier),
        ('rfc', random_forest_classifier),
        ('svmc', svm)
    ],
    voting='hard'  
)
voting_classifier.fit(x_train, y_train)
# Out:
# VotingClassifier(estimators=[('lrc',
#                               Pipeline(steps=[('tfidf',
#                                                TfidfVectorizer(max_df=0.8,
#                                                                max_features=5000,
#                                                                min_df=3,
#                                                                ngram_range=(1,
#                                                                             5),
#                                                                sublinear_tf=True)),
#                                               ('lrc',
#                                                LogisticRegression(max_iter=1000,
#                                                                   random_state=42))])),
#                              ('knn',
#                               Pipeline(steps=[('tfidf',
#                                                TfidfVectorizer(max_df=0.8,
#                                                                max_features=5000,
#                                                                min_df=3,
#                                                                ngram_range=(1,
#                                                                             5),
#                                                                stop_words='english',
#                                                                sublinear_t...
#                                                TfidfVectorizer(max_df=0.8,
#                                                                max_features=5000,
#                                                                min_df=3,
#                                                                ngram_range=(1,
#                                                                             5),
#                                                                stop_words='english',
#                                                                sublinear_tf=True)),
#                                               ('rfc',
#                                                RandomForestClassifier(n_estimators=400,
#                                                                       random_state=42))])),
#                              ('svmc',
#                               Pipeline(steps=[('tfidf',
#                                                TfidfVectorizer(max_df=0.8,
#                                                                max_features=5000,
#                                                                min_df=3,
#                                                                ngram_range=(1,
#                                                                             5),
#                                                                stop_words='english',
#                                                                sublinear_tf=True)),
#                                               ('svmc',
#                                                SVC(random_state=42))]))])

# %%
y_pred = voting_classifier.predict(x_test)
accuracy = accuracy_score(y_pred, y_test)
print("Models Accuracy:", accuracy)
# Out:
# Models Accuracy: 0.7493248219985269

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(5, 3))
class_names = mental_health['label'].unique()
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()

# %%
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
# SuicideWatch       0.73      0.78      0.76      2029
#   depression       0.77      0.72      0.74      2044
#
#     accuracy                           0.75      4073
#    macro avg       0.75      0.75      0.75      4073
# weighted avg       0.75      0.75      0.75      4073

# %% [markdown]
# # User input

# %%
import re
stop_words = set(stopwords.words('english'))

# Processing User Input
def preprocess(input_text):
    input_text = input_text.lower()
    input_text = re.sub(r'[^\w\s]+', '', input_text)
    input_words = input_text.split()
    stop_words = set(stopwords.words('english'))
    input_words = [word for word in input_words if word not in stop_words]
    cleaned_text = ' '.join(input_words)

    return cleaned_text


text = preprocess("I wake up every day feeling like there's a heavy weight on my chest. It's hard to find joy in anything anymore. Simple tasks that used to be easy now feel impossible. I can't escape these dark thoughts that keep swirling in my head, telling me I'm worthless and that life is meaningless. It's like a never-ending cycle of despair, and I don't see any way out of it. I just want the pain to stop.")
print(text)

class_probs = lr.predict_proba([text])[0]

depressed_percentage = class_probs[1] * 100
suicide_watch_percentage = class_probs[0] * 100

if text == "":
    print("The string is empty")
else:
    if depressed_percentage > suicide_watch_percentage:
        print("The Text Is Classified as Depressed: ", depressed_percentage)
    else:
        print("The Text Is Classified as Sucidial", suicide_watch_percentage)
# Out:
# wake every day feeling like theres heavy weight chest hard find joy anything anymore simple tasks used easy feel impossible cant escape dark thoughts keep swirling head telling im worthless life meaningless like neverending cycle despair dont see way want pain stop
# The Text Is Classified as Depressed:  73.45315964010777
